# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import make_scorer, accuracy_score, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from sklearn.feature_extraction import text
import nltk

# %%
# Download stop words
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/chloelam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Combine stop words from English, French, German, Spanish, Chinese, Japanese, and Korean
stop_words_en = text.ENGLISH_STOP_WORDS
stop_words_fr = stopwords.words('french')
stop_words_de = stopwords.words('german')
stop_words_es = stopwords.words('spanish')
# For Chinese, Japanese, Korean, we need to manually specify or use external libraries as nltk does not provide them.
stop_words_zh = set()  # Placeholder, add actual stop words
stop_words_ja = set()  # Placeholder, add actual stop words
stop_words_ko = set()  # Placeholder, add actual stop words

# %%
# Create a combined list of stop words
stop_words_combined = list(set(stop_words_en).union(stop_words_fr).union(stop_words_de).union(stop_words_es).union(stop_words_zh).union(stop_words_ja).union(stop_words_ko))

# %%
df_fullsent = pd.read_csv('fulldata_sentiment_analysis_results.csv')
df_fullsent.sample(20)
# Out:
#            queue priority language  \
# 5353  ACCOUNTING     HIGH       DE
# 452     SOFTWARE   MEDIUM       ES
# 63      HARDWARE   MEDIUM       EN
# 8353    HARDWARE      LOW       ES
# 1725  ACCOUNTING   MEDIUM       ES
# 409   ACCOUNTING     HIGH       EN
# 1696    HARDWARE      LOW       FR
# 6399    SOFTWARE   MEDIUM       EN
# 1947    SOFTWARE     HIGH       EN
# 3099    HARDWARE     HIGH       EN
# 3785  ACCOUNTING     HIGH       EN
# 5493    HARDWARE     HIGH       DE
# 6755    SOFTWARE     HIGH       ES
# 8137  ACCOUNTING     HIGH       EN
# 3300  ACCOUNTING     HIGH       EN
# 4492    HARDWARE   MEDIUM       EN
# 8269    HARDWARE      LOW       EN
# 7178  ACCOUNTING      LOW       EN
# 5348    HARDWARE     HIGH       DE
# 915   ACCOUNTING     HIGH       EN
#
#                                           subcategory  \
# 5353                   Employee Inquiries::Accounting
# 452                                    Messaging Apps
# 63                                  Smart-Kinderwagen
# 8353                            Smart-Luftentfeuchter
# 1725   Employee Inquiries::IT Support::Network Issues
# 409    Employee Inquiries::Legal Inquiries::Labor Law
# 1696                                  360-Grad-Kamera
# 6399                                 Illustrator 2022
# 1947                                     Data Privacy
# 3099                    DualSense Wireless Controller
# 3785            Customer Inquiries::Technical Support
# 5493                                             Yoga
# 6755                                          Ulysses
# 8137          Employee Inquiries::Accounting::Payroll
# 3300                       Customer Inquiries::Praise
# 4492                                 Portable Console
# 8269                                              IMU
# 7178                     Customer Inquiries::Payments
# 5348                                    Thermal Paste
# 915   Employee Inquiries::Accounting::Travel Expenses
#
#                                                 subject  \
# 5353         Dringend – Einzugsermächtigung korrigieren
# 452   Actualización de Versión de Aplicación de Mens...
# 63                         Issue with Smart Kinderwagen
# 8353  Detalles de la Factura - Cambio de nombre de e...
# 1725  Consulta sobre actualización de software y err...
# 409           Urgent: Legal Inquiry Regarding Labor Law
# 1696         Demande de mise à jour - Caméra 360 degrés
# 6399                 Illustrator 2022 - Upgrade Inquiry
# 1947       URGENT: Can't Sign Into Data Privacy Account
# 3099           Help! DualSense Controller won't turn on
# 3785            Urgent: Locked Out of Financial Account
# 5493          Yoga Laptop startet nicht mehr – dringend
# 6755        ¡¡URGENTE!! No funciona el software Ulysses
# 8137  Urgent: Unable to access payroll system - Hack...
# 3300  Security Issue in QuickPay 4.6 - Immediate Upd...
# 4492       Issue with Portable Console - Screen Stripes
# 8269                Minor Issue with IMU Update Inquiry
# 7178                   Inquiry Regarding Invoice Update
# 5348              Dringend: Rechner startet nicht mehr!
# 915   URGENT: Unable to access travel expense applic...
#
#                                                    text  \
# 5353  Sehr geehrtes Team, bitte korrigieren Sie mein...
# 452   Hola equipo de soporte, he observado algunos e...
# 63    The Smart-Kinderwagen display has freezed. Reb...
# 8353  Quería saber si es posible actualizar la factu...
# 1725  Hola equipo de soporte, recientemente he notad...
# 409   Dear Support, I urgently need to speak to some...
# 1696  Bonjour, j'aimerais savoir si une mise à jour ...
# 6399  Hi there, I'm currently using Adobe Illustrato...
# 1947  My Data Privacy account appears to be compromi...
# 3099  My DualSense Wireless Controller won't turn on...
# 3785  Dear Support Team, I cannot access my online f...
# 5493  Liebes Support-Team, mein Yoga Laptop lässt si...
# 6755  Hola equipo de soporte, he intentado abrir Uly...
# 8137  Hello, I am unable to access our payroll syste...
# 3300  Hello Support, I have discovered a serious vul...
# 4492  Hello Support Team, I've recently noticed some...
# 8269  Dear Support Team, I noticed a minor glitch wi...
# 7178  Can my next invoice reflect the new company name?
# 5348  Hallo Support-Team, aktuell lässt sich mein Re...
# 915   My travel expense app isn't working and I need...
#
#                                               sentiment sentiment_label  \
# 5353   {'label': 'neutral', 'score': 0.583605170249939}         neutral
# 452   {'label': 'neutral', 'score': 0.7921431064605713}         neutral
# 63    {'label': 'negative', 'score': 0.8509384989738...        negative
# 8353  {'label': 'neutral', 'score': 0.8107450604438782}         neutral
# 1725  {'label': 'neutral', 'score': 0.7304739356040955}         neutral
# 409   {'label': 'neutral', 'score': 0.5330340266227722}         neutral
# 1696  {'label': 'neutral', 'score': 0.7224858403205872}         neutral
# 6399  {'label': 'neutral', 'score': 0.6901986002922058}         neutral
# 1947  {'label': 'negative', 'score': 0.8848888278007...        negative
# 3099  {'label': 'negative', 'score': 0.8186317682266...        negative
# 3785  {'label': 'negative', 'score': 0.8657691478729...        negative
# 5493  {'label': 'neutral', 'score': 0.7379912734031677}         neutral
# 6755  {'label': 'neutral', 'score': 0.7777913212776184}         neutral
# 8137  {'label': 'negative', 'score': 0.8443670868873...        negative
# 3300  {'label': 'negative', 'score': 0.8249921202659...        negative
# 4492  {'label': 'negative', 'score': 0.8300695419311...        negative
# 8269  {'label': 'neutral', 'score': 0.5145341753959656}         neutral
# 7178  {'label': 'neutral', 'score': 0.9273156523704529}         neutral
# 5348  {'label': 'neutral', 'score': 0.5808266401290894}         neutral
# 915   {'label': 'negative', 'score': 0.8474606871604...        negative
#
#       sentiment_score
# 5353         0.583605
# 452          0.792143
# 63           0.850938
# 8353         0.810745
# 1725         0.730474
# 409          0.533034
# 1696         0.722486
# 6399         0.690199
# 1947         0.884889
# 3099         0.818632
# 3785         0.865769
# 5493         0.737991
# 6755         0.777791
# 8137         0.844367
# 3300         0.824992
# 4492         0.830070
# 8269         0.514534
# 7178         0.927316
# 5348         0.580827
# 915          0.847461

# %%
# Preprocessing text data
vectorizer = TfidfVectorizer(stop_words=stop_words_combined, max_features=1000)
X = vectorizer.fit_transform(df_fullsent['text'])

# %%
# Encoding target variables
le_queue = LabelEncoder()
le_priority = LabelEncoder()
le_language = LabelEncoder()
le_sentiment_label = LabelEncoder()

y_queue = le_queue.fit_transform(df_fullsent['queue'])
y_priority = le_priority.fit_transform(df_fullsent['priority'])
y_language = le_language.fit_transform(df_fullsent['language'])
y_sentiment_label = le_sentiment_label.fit_transform(df_fullsent['sentiment_label'])
y_sentiment_score = df_fullsent['sentiment_score']

y_classification = pd.DataFrame({
    'queue': y_queue,
    'priority': y_priority,
    'language': y_language,
    'sentiment_label': y_sentiment_label
})

# %%
# Splitting the data into training and testing sets
X_train, X_test, y_train_classification, y_test_classification, y_train_score, y_test_score = train_test_split(
    X, y_classification, y_sentiment_score, test_size=0.2, random_state=42
)

# %%
# Model Training for classification targets
classifier = MultiOutputClassifier(RandomForestClassifier(random_state=42))
classifier.fit(X_train, y_train_classification)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(random_state=42))

# %%
# Model Training for regression target (sentiment_score)
regressor = RandomForestRegressor(random_state=42)
regressor.fit(X_train, y_train_score)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Function to apply the trained model to new data and include new text data in the DataFrame
def apply_model_with_text(new_text_data, vectorizer, classifier, regressor, le_queue, le_priority, le_language, le_sentiment_label):
    # Preprocess the new text data
    X_new = vectorizer.transform(new_text_data)
    
    # Make predictions for classification targets
    y_pred_classification = classifier.predict(X_new)
    
    # Make predictions for regression target
    y_pred_score = regressor.predict(X_new)
    
    # Convert predictions to DataFrame
    y_pred_classification_df = pd.DataFrame(y_pred_classification, columns=['queue', 'priority', 'language', 'sentiment_label'])
    y_pred_classification_df['sentiment_score'] = y_pred_score
    
    # Inverse transform the predictions to get the original labels
    y_pred_classification_df['queue'] = le_queue.inverse_transform(y_pred_classification_df['queue'])
    y_pred_classification_df['priority'] = le_priority.inverse_transform(y_pred_classification_df['priority'])
    y_pred_classification_df['language'] = le_language.inverse_transform(y_pred_classification_df['language'])
    y_pred_classification_df['sentiment_label'] = le_sentiment_label.inverse_transform(y_pred_classification_df['sentiment_label'])
    
    # Include the new text data in the DataFrame
    y_pred_classification_df['text'] = new_text_data
    
    return y_pred_classification_df

# %%
# Example new text data including Chinese, Japanese, and Korean
new_text_data = [
    "Hello, I'm having trouble with my DVD player. It won't turn on. Please help!",
    "Dear support team, the software update caused issues with my CRM system.",
    "My Intel NUC is not booting up after the latest update.",
    "Urgent: CyberLink PowerDirector 19 won't launch after installation.",
    "Problem with Apple App Store Connect - security settings need to be updated.",
    "你好，我的DVD播放器有问题。 它无法启动。 请帮忙！",  # Chinese
    "こんにちは、DVDプレーヤーの調子が悪いです。 電源が入りません。 助けてください！",  # Japanese
    "안녕하세요, 제 DVD 플레이어에 문제가 있습니다. 켜지지 않습니다. 도와주세요!"  # Korean
]

# Apply the model to new data and include new text data in the DataFrame
predictions_with_text = apply_model_with_text(new_text_data, vectorizer, classifier, regressor, le_queue, le_priority, le_language, le_sentiment_label)

# Display the predictions with text
predictions_with_text
# Out:
#         queue priority language sentiment_label  sentiment_score  \
# 0    HARDWARE     HIGH       EN        negative         0.860114
# 1  ACCOUNTING   MEDIUM       EN         neutral         0.776123
# 2    HARDWARE   MEDIUM       EN         neutral         0.828454
# 3    SOFTWARE     HIGH       EN        negative         0.846186
# 4    HARDWARE     HIGH       EN        negative         0.854888
# 5  ACCOUNTING      LOW       EN         neutral         0.819955
# 6  ACCOUNTING      LOW       EN         neutral         0.819955
# 7  ACCOUNTING      LOW       EN         neutral         0.819955
#
#                                                 text
# 0  Hello, I'm having trouble with my DVD player. ...
# 1  Dear support team, the software update caused ...
# 2  My Intel NUC is not booting up after the lates...
# 3  Urgent: CyberLink PowerDirector 19 won't launc...
# 4  Problem with Apple App Store Connect - securit...
# 5                        你好，我的DVD播放器有问题。 它无法启动。 请帮忙！
# 6         こんにちは、DVDプレーヤーの調子が悪いです。 電源が入りません。 助けてください！
# 7      안녕하세요, 제 DVD 플레이어에 문제가 있습니다. 켜지지 않습니다. 도와주세요!
